# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_pickle ('/content/drive/MyDrive/HS651_CAMs_systematic_review_automation/df_fulltext88.pkl')

# %%
 df.head()
# Out:
#                                                 Title  ... FuL
# 1   "Tai Chi Chih Compared With Cognitive Behavior...  ...   1
# 2   "Cognitive behavioral therapy vs. Tai Chi for ...  ...   1
# 3   "Tai chi/yoga reduces prenatal depression, anx...  ...   1
# 5   "Randomized controlled trial of Qigong/Tai Chi...  ...   1
# 13  "Mindfulness meditation and improvement in sle...  ...   0
#
# [5 rows x 9 columns]

# %%
#df['AbstractPlusTitle'][1]

# %%
len(df)
# Out:
# 88

# %%
PMCIDs = [str(x) for x in df['PMCID']]

# %%
PMCIDs = [x for x in PMCIDs if str(x) != 'nan']

# %%
PMCIDs[55] = 'PMC7607921'

# %%
#for i in range(len(PMCIDs)):
  #print(i)
  #print(PMCIDs[i])

# %%
len(PMCIDs)
# Out:
# 87

# %%
PMClink = ['http://www.ncbi.nlm.nih.gov/pmc/articles/' + id + '/pdf' for id in PMCIDs]

# %%
PMClink
# Out:
# ['http://www.ncbi.nlm.nih.gov/pmc/articles/PMC5549450/pdf',
#  'http://www.ncbi.nlm.nih.gov/pmc/articles/PMC4153053/pdf',
#  'http://www.ncbi.nlm.nih.gov/pmc/articles/PMC3730281/pdf',
#  'http://www.ncbi.nlm.nih.gov/pmc/articles/PMC4329282/pdf',
#  'http://www.ncbi.nlm.nih.gov/pmc/articles/PMC4407465/pdf',
#  'http://www.ncbi.nlm.nih.gov/pmc/articles/PMC3247625/pdf',
#  'http://www.ncbi.nlm.nih.gov/pmc/articles/PMC5874181/pdf',
#  'http://www.ncbi.nlm.nih.gov/pmc/articles/PMC4959048/pdf',
#  'http://www.ncbi.nlm.nih.gov/pmc/articles/PMC4698327/pdf',
#  'http://www.ncbi.nlm.nih.gov/pmc/articles/PMC3099500/pdf',
#  'http://www.ncbi.nlm.nih.gov/pmc/articles/PMC4331267/pdf',
#  'http://www.ncbi.nlm.nih.gov/pmc/articles/PMC5118018/pdf',
#  'http://www.ncbi.nlm.nih.gov/pmc/articles/PMC3353275/pdf',
#  'http://www.ncbi.nlm.nih.gov/pmc/articles/PMC3871975/pdf',
#  'http://www.ncbi.nlm.nih.gov/pmc/articles/PMC4648965/pdf',
#  'http://www.ncbi.nlm.nih.gov/pmc/articles/PMC4393338/pdf',
# ...

# %%
import urllib3
import os

# %%
urllib3.disable_warnings()
http = urllib3.PoolManager()

print("downloading PDFs")
for url,id in zip(PMClink,PMCIDs):
  r = http.request('GET',url)
  pdf_save = "/content/drive/MyDrive/fulltext_87"
  filename = str(id) + '.pdf'
  completeName = os.path.join(pdf_save,filename) 
  with open(completeName,'wb') as fcont:
    fcont.write(r.data)
# Out:
# downloading PDFs

# %% [markdown]
# MaxRetryError: HTTPSConnectionPool(host='www.ncbi.nlm.nih.gov', port=443): Max retries exceeded with url: /pmc/articles/PMC5438893/pdf/nihms859138.pdf (Caused by ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')))

# %%
# Batch convert PDFfiles to text and save them in Mydrive

# %%
#!pip install pdfminer.six Alternativ to PDFpy2

# %%
#from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
#from pdfminer.converter import TextConverter
#from pdfminer.layout import LAParams
#from pdfminer.pdfpage import PDFPage
#from pdfminer.pdfparser import PDFParser
#from pdfminer.pdfdocument import PDFDocument
#from io import StringIO
#import os
#import glob

# %%
import os
import glob

# %%
#!--NotebookApp.iopub_data_rate_limit

# %%
#In Python, the glob module is used to retrieve files/pathnames matching a specified pattern.
directory = os.path.abspath("/content/drive/MyDrive/fulltext_87")
#pdf_dir = "/content/drive/MyDrive/fulltext" this is a relatie path; cannot identify
#pdfFiles = glob.glob("%s*.pdf" % pdf_dir)
pdfFiles = glob.glob(os.path.join(directory, '*.pdf'))

# %%
# !pip install tika
# Out:
# ...
#   Created wheel for tika: filename=tika-1.24-cp37-none-any.whl size=32894 sha256=d9fc4f478e3468e4ef01ea10c3fa8202dd78ffaed8fe7ad72a26a4ed7a96f183
#   Stored in directory: /root/.cache/pip/wheels/73/9c/f5/0b1b738442fc2a2862bef95b908b374f8e80215550fb2a8975
# Successfully built tika
# ...

# %%
from tika import parser

# %%
for one_pdf in pdfFiles:
  pdf_file = open(one_pdf,mode='r')
  parsed_pdf = parser.from_file(one_pdf)
  savepath = "/content/drive/MyDrive/fulltext_87/"
  filenameString = str(one_pdf[:-4]) + ".fulltxt"
  completeName = os.path.join(savepath,filenameString)
  text_file = open(completeName, "w")
  text_file.write(parsed_pdf["content"])
text_file.close()
pdf_file.close()
# Out:
# 2021-06-07 22:17:13,606 [MainThread  ] [INFO ]  Retrieving http://search.maven.org/remotecontent?filepath=org/apache/tika/tika-server/1.24/tika-server-1.24.jar to /tmp/tika-server.jar.
# 2021-06-07 22:17:14,520 [MainThread  ] [INFO ]  Retrieving http://search.maven.org/remotecontent?filepath=org/apache/tika/tika-server/1.24/tika-server-1.24.jar.md5 to /tmp/tika-server.jar.md5.
# 2021-06-07 22:17:14,924 [MainThread  ] [WARNI]  Failed to see startup log message; retrying...

# %% [markdown]
# # Sanity check of the fulltext pdf and correct the sparsed text file with Jas's fixed text

# %%
#remove PMC7875700.pdf (openaccess but no pdf version)
#remove PMC7270860.pdf (openaccess but no pdf version)
#remove PMC6734672.pdf (openaccess but no pdf version)
#remove PMC6396935.pdf (openaccess but no pdf version)
#remove PMC5861462.pdf (openaccess but no pdf version) Wang et al., 2018 tai chi versus aerobic exercise
#remove PMC5405291.pdf (openaccess but no pdf version)

# %%
print(df[df['PMCID']=='PMC6517157'].index.values)
# Out:
# [377]

# %%
df['FuL'][377]
# Out:
# 0

# %%
print(df[df['PMCID']=='PMC5405291'].index.values)
# Out:
# [70]

# %%
df['AbL'][70]
# Out:
# 1

# %%
print(df[df['PMCID']=='PMC4634734'].index.values)
# Out:
# []

# %%
print(df[df['PMCID']=='PMC4257149'].index.values)
# Out:
# []

# %%
print(df[df['PMCID']=='PMC3711236'].index.values)
# Out:
# []

# %%
directory = os.path.abspath("/content/drive/MyDrive/fulltext_87/")
TxtFiles = glob.glob(os.path.join(directory, '*.fulltxt'))

# %%
print(TxtFiles)
# Out:
# ['/content/drive/MyDrive/fulltext_87/PMC5549450.fulltxt', '/content/drive/MyDrive/fulltext_87/PMC4329282.fulltxt', '/content/drive/MyDrive/fulltext_87/PMC4407465.fulltxt', '/content/drive/MyDrive/fulltext_87/PMC5874181.fulltxt', '/content/drive/MyDrive/fulltext_87/PMC4959048.fulltxt', '/content/drive/MyDrive/fulltext_87/PMC4698327.fulltxt', '/content/drive/MyDrive/fulltext_87/PMC4331267.fulltxt', '/content/drive/MyDrive/fulltext_87/PMC5118018.fulltxt', '/content/drive/MyDrive/fulltext_87/PMC4648965.fulltxt', '/content/drive/MyDrive/fulltext_87/PMC4393338.fulltxt', '/content/drive/MyDrive/fulltext_87/PMC4072122.fulltxt', '/content/drive/MyDrive/fulltext_87/PMC4972683.fulltxt', '/content/drive/MyDrive/fulltext_87/PMC5546134.fulltxt', '/content/drive/MyDrive/fulltext_87/PMC5810370.fulltxt', '/content/drive/MyDrive/fulltext_87/PMC4738064.fulltxt', '/content/drive/MyDrive/fulltext_87/PMC5101089.fulltxt', '/content/drive/MyDrive/fulltext_87/PMC5221754.fulltxt', '/content/drive/MyDrive/full
# ...

# %%
import re
import pickle
import spacy
import numpy as np
from spacy.lang.en import English

# %%
spacy_stopwords = spacy.lang.en.stop_words.STOP_WORDS

# %%
nlp = spacy.load('en')

# %%
nlp.Defaults.stop_words -= {"will","had","was","were","did"}

# %%
new_stopwords = spacy_stopwords

# %%
def clean_text(x):
  x = x.lower().split()
  new_list = []
  for word in x:
    if word not in new_stopwords: 
      new_list.append(word)
  return " ".join(new_list)

# %%
# to get only text in between introduction and references
# find (first occurence) , rfind (find last  occurence) are python string methods
def preprocess(x):
    start = "introduction"
    end = "reference"
    x =  x[x.find(start)+len(start):x.rfind(end)]
    return x

# %%
for one_txt in TxtFiles:
    ft = open(one_txt,'rt')
    txt = ft.read()
    txt = clean_text(txt)
    txt = preprocess(txt)
    savepath = "/content/drive/MyDrive/fulltext_87/"
    filenameString = str(one_txt[:-8]) + "clean"+".txt"
    completeName = os.path.join(savepath,filenameString)
    text_file = open(completeName, "w")
    text_file.write(txt)
    ft.close()

# %%
directory = os.path.abspath("/content/drive/MyDrive/fulltext_87/")
cleantxt = glob.glob(os.path.join(directory, '*.txt'))

# %%
for cleant in cleantxt:
    ft = open(cleant,'rt')
    txt = ft.read()
    print(txt)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# #Haystack_QA_pipeline fine_tunning and validation

# %%
#### find-tune model on my own data
#####https://github.com/deepset-ai/haystack/blob/master/tutorials/Tutorial2_Finetune_a_model_on_your_data.ipynb

# %%
# Make sure you have a GPU running
# !nvidia-smi
# Out:
# Wed Jun 16 21:39:08 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.27       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# Install the latest release of Haystack in your own environment 
#! pip install farm-haystack

# Install the latest master of Haystack
# !pip install git+https://github.com/deepset-ai/haystack.git
# !pip install grpcio-tools==1.34.1
# Out:
# ...
#   Cloning https://github.com/deepset-ai/haystack.git to /tmp/pip-req-build-ds0lksgj
#   Running command git clone -q https://github.com/deepset-ai/haystack.git /tmp/pip-req-build-ds0lksgj
# ...
#      |████████████████████████████████| 215kB 8.2MB/s
# ...
#      |████████████████████████████████| 51kB 6.5MB/s
# ...
#      |████████████████████████████████| 51kB 8.6MB/s
# ...
#      |████████████████████████████████| 81kB 10.1MB/s
# ...
#      |████████████████████████████████| 327kB 28.0MB/s
# ...
#      |████████████████████████████████| 337kB 35.6MB/s
# ...
#      |████████████████████████████████| 92kB 11.9MB/s
# ...
#      |████████████████████████████████| 983kB 36.1MB/s
# ...
#      |████████████████████████████████| 5.6MB 47.7MB/s
# ...
#      |████████████████████████████████| 102kB 13.4MB/s
# ...
#      |████████████████████████████████| 8.4MB 46.8MB/s
# ...
#      |████████████████████████████████| 348kB 44.4MB/s
# ...
#      |████████████████████████████████| 61kB 9.2MB/s
# ...
#      |████████████████████████████████| 51kB 8.2MB/s
# ...

# %%
from haystack.reader.farm import FARMReader
# Out:
# 06/08/2021 01:48:06 - INFO - faiss.loader -   Loading faiss with AVX2 support.
# 06/08/2021 01:48:06 - INFO - faiss.loader -   Could not load library with AVX2 support due to:
# ModuleNotFoundError("No module named 'faiss.swigfaiss_avx2'")
# 06/08/2021 01:48:06 - INFO - faiss.loader -   Loading faiss.
# 06/08/2021 01:48:06 - INFO - faiss.loader -   Successfully loaded faiss.
# 06/08/2021 01:48:08 - INFO - farm.modeling.prediction_head -   Better speed can be achieved with apex installed from https://www.github.com/nvidia/apex .

# %%
#fine-tune scibert QA model (use training data generated from haystack annotation tool)

# %%
reader = FARMReader(model_name_or_path="ktrapeznikov/scibert_scivocab_uncased_squad_v2",use_gpu=True)
## train_data = "PATH/TO_YOUR/TRAIN_DATA" 
train_data = '/content/drive/MyDrive/HS651_CAMs_systematic_review_automation/pipeline on PMCfullarticles'
reader.train(data_dir=train_data, train_filename="answers20.json", use_gpu=True, n_epochs=1, save_dir="my_model")
# Out:
# 06/16/2021 21:55:04 - INFO - farm.utils -   Using device: CUDA
# 06/16/2021 21:55:04 - INFO - farm.utils -   Number of GPUs: 1
# 06/16/2021 21:55:04 - INFO - farm.utils -   Distributed Training: False
# 06/16/2021 21:55:04 - INFO - farm.utils -   Automatic Mixed Precision: None
# 06/16/2021 21:55:04 - INFO - filelock -   Lock 139861945246864 acquired on /root/.cache/huggingface/transformers/37fcec8deea7e51dad097a81fac824c77907154c468467c3239fcba85340c690.e3b74e14e523e9b4e6028a5c22fc3ce679358f46079027fdb192df133fddaa24.lock
# ...
# 06/16/2021 21:55:04 - INFO - filelock -   Lock 139861945246864 released on /root/.cache/huggingface/transformers/37fcec8deea7e51dad097a81fac824c77907154c468467c3239fcba85340c690.e3b74e14e523e9b4e6028a5c22fc3ce679358f46079027fdb192df133fddaa24.lock
# ...

# %%
# Saving the model happens automatically at the end of training into the `save_dir` you specified
# However, you could also save a reader manually again via:
reader.save(directory="/content/drive/MyDrive/HS651_CAMs_systematic_review_automation/pipeline on PMCfullarticles/my_model")
# Out:
# 06/16/2021 22:01:24 - INFO - haystack.reader.farm -   Saving reader model to /content/drive/MyDrive/HS651_CAMs_systematic_review_automation/pipeline on PMCfullarticles/my_model

# %%
# If you want to load it at a later point, just do:
#new_reader = FARMReader(model_name_or_path="my_model")

# %%
##### sci-bert for Q&A

# %%
# Batch processing
#error 1: repeated with first doc content; Solution: document_store.delete_all_documents()

# %% [markdown]
# # Question-answering haysatack pipeline on Fulltext

# %%
# In Colab / No Docker environments: Start Elasticsearch from source
! wget https://artifacts.elastic.co/downloads/elasticsearch/elasticsearch-7.9.2-linux-x86_64.tar.gz -q
! tar -xzf elasticsearch-7.9.2-linux-x86_64.tar.gz
! chown -R daemon:daemon elasticsearch-7.9.2

import os
from subprocess import Popen, PIPE, STDOUT
es_server = Popen(['elasticsearch-7.9.2/bin/elasticsearch'],
                   stdout=PIPE, stderr=STDOUT,
                   preexec_fn=lambda: os.setuid(1)  # as daemon
                  )
# wait until ES has started
! sleep 30

# %%
# Connect to Elasticsearch

from haystack.document_store.elasticsearch import ElasticsearchDocumentStore
document_store = ElasticsearchDocumentStore(host="localhost", username="", password="", index="document")
# Out:
# 06/16/2021 22:32:34 - INFO - elasticsearch -   HEAD http://localhost:9200/ [status:200 request:0.008s]
# 06/16/2021 22:32:35 - INFO - elasticsearch -   PUT http://localhost:9200/document [status:200 request:0.239s]
# 06/16/2021 22:32:35 - INFO - elasticsearch -   PUT http://localhost:9200/label [status:200 request:0.193s]

# %%
reader = FARMReader(model_name_or_path='/content/drive/MyDrive/HS651_CAMs_systematic_review_automation/pipeline on PMCfullarticles/my_model', use_gpu=True)
# Out:
# 06/16/2021 22:36:49 - INFO - farm.utils -   Using device: CUDA
# 06/16/2021 22:36:49 - INFO - farm.utils -   Number of GPUs: 1
# 06/16/2021 22:36:49 - INFO - farm.utils -   Distributed Training: False
# 06/16/2021 22:36:49 - INFO - farm.utils -   Automatic Mixed Precision: None
# 06/16/2021 22:36:51 - WARNING - farm.modeling.prediction_head -   Some unused parameters are passed to the QuestionAnsweringHead. Might not be a problem. Params: {"training": true, "num_labels": 2, "ph_output_type": "per_token_squad", "model_type": "span_classification", "label_tensor_name": "question_answering_label_ids", "label_list": ["start_token", "end_token"], "metric": "squad", "name": "QuestionAnsweringHead"}
# 06/16/2021 22:36:51 - WARNING - farm.utils -   ML Logging is turned off. No parameters, metrics or artifacts will be logged to MLFlow.
# 06/16/2021 22:36:51 - INFO - farm.utils -   Using device: CUDA
# 06/16/2021 22:36:51 - INFO - farm.utils -   Number of GPUs: 1
# ...

# %%
import os
import glob

directory = os.path.abspath("/content/drive/MyDrive/fulltext_87(79)")
cleantxt = glob.glob(os.path.join(directory, '*clean.txt'))

# %%
import pandas as pd

# %%
from haystack.file_converter.txt import TextConverter
#from haystack.file_converter.pdf import PDFToTextConverter
from haystack.preprocessor.preprocessor import PreProcessor
from haystack.retriever.sparse import ElasticsearchRetriever
#from haystack.pipeline import ExtractiveQAPipeline
converter = TextConverter(remove_numeric_tables=True, valid_languages=["en"])


savepath = "/content/drive/MyDrive/fulltext__87(79)/"

for cleant in cleantxt:
  if os.path.getsize(cleant) > 10:
     document_store.delete_all_documents()
     doc_txt = converter.convert(file_path=cleant,meta=None)  
     preprocessor_sliding_window = PreProcessor(
       split_overlap=6,
       split_length=500,
       split_respect_sentence_boundary=True,
       clean_empty_lines=True,
       clean_whitespace=True,
       clean_header_footer=True)


     docs_sliding_window = preprocessor_sliding_window.process(doc_txt)

     document_store.write_documents(docs_sliding_window)
     retriever = ElasticsearchRetriever(document_store=document_store)
     from haystack.pipeline import ExtractiveQAPipeline
     pipe = ExtractiveQAPipeline(reader, retriever)
     
     try:
       prediction1 = pipe.run(query="what are the treatment groups?", top_k_retriever=10, top_k_reader=5)
       #prediction1 = pipe.run(query="what are the treatment/intervention groups?", top_k_retriever=10, top_k_reader=5)
       predictiondata1 = [[prediction1['query'],prediction1['answers'][1]['answer'],prediction1['answers'][1]['context']],
        [prediction1['query'],prediction1['answers'][2]['answer'],prediction1['answers'][2]['context']],
        [prediction1['query'],prediction1['answers'][3]['answer'],prediction1['answers'][3]['context']]]
       prediction2 = pipe.run(query="what is the scale of sleep measure?", top_k_retriever=10, top_k_reader=5)
       predictiondata2 = [[prediction2['query'],prediction2['answers'][0]['answer'],prediction2['answers'][0]['context']],
        [prediction2['query'],prediction2['answers'][1]['answer'],prediction2['answers'][1]['context']],
        [prediction2['query'],prediction2['answers'][2]['answer'],prediction2['answers'][2]['context']]]
       prediction3 = pipe.run(query="what is the scale of depression measure?", top_k_retriever=10, top_k_reader=5)
       predictiondata3 = [[prediction3['query'],prediction3['answers'][1]['answer'],prediction3['answers'][1]['context']],
        [prediction3['query'],prediction3['answers'][2]['answer'],prediction3['answers'][2]['context']],
        [prediction3['query'],prediction3['answers'][3]['answer'],prediction3['answers'][3]['context']]]
       prediction4 = pipe.run(query="what is the scale of anxiety measure?", top_k_retriever=10, top_k_reader=5)
       predictiondata4 = [[prediction4['query'],prediction4['answers'][1]['answer'],prediction4['answers'][1]['context']],
        [prediction4['query'],prediction4['answers'][2]['answer'],prediction4['answers'][2]['context']],
        [prediction4['query'],prediction4['answers'][3]['answer'],prediction4['answers'][3]['context']]]
       prediction5 = pipe.run(query="how long is the intervention?", top_k_retriever=10, top_k_reader=5)
       predictiondata5 = [[prediction5['query'],prediction5['answers'][1]['answer'],prediction5['answers'][1]['context']],
        [prediction5['query'],prediction5['answers'][2]['answer'],prediction5['answers'][2]['context']],
        [prediction5['query'],prediction5['answers'][3]['answer'],prediction5['answers'][3]['context']]]
     except:
       continue
     df1 = pd.DataFrame(predictiondata1, columns = ['Question', 'Answer','Context'])
     df2 = pd.DataFrame(predictiondata2, columns = ['Question', 'Answer','Context'])
     df3 = pd.DataFrame(predictiondata3, columns = ['Question', 'Answer','Context'])
     df4 = pd.DataFrame(predictiondata4, columns = ['Question', 'Answer','Context'])
     df5 = pd.DataFrame(predictiondata5, columns = ['Question', 'Answer','Context'])
     dflist = [df1,df2,df3,df4,df5]
     queriesdfs = pd.concat(dflist)
     filenameString = str(cleant[:-4]) + ".pkl"
     completeName = os.path.join(savepath,filenameString)
     queriesdfs.to_pickle(completeName)
# Out:
# 06/16/2021 22:49:42 - WARNING - haystack.document_store.elasticsearch -   DEPRECATION WARNINGS:
#                 1. delete_all_documents() method is deprecated, please use delete_documents method
#                 For more details, please refer to the issue: https://github.com/deepset-ai/haystack/issues/1045
#
# 06/16/2021 22:49:42 - INFO - elasticsearch -   POST http://localhost:9200/document/_delete_by_query [status:200 request:0.019s]
# 06/16/2021 22:49:45 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:0.977s]
# 06/16/2021 22:49:45 - INFO - elasticsearch -   POST http://localhost:9200/document/_search [status:200 request:0.007s]
# ...
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 30.54 Batches/s]
# 06/16/2021 22:49:46 - INFO - elasticsearch -   POST http://localhost:9200/document/_search [status:200 request:0.015s]
# ...
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  9.23 Batches/s]
# ...

# %%
PMC2999703a = pd.read_pickle ('/content/drive/MyDrive/fulltext_87(79)/PMC2999703.fulltxt.pkl')
PMC2999703a

# %%
import pandas as pd
PMC8009331b = pd.read_pickle('/content/drive/MyDrive/fulltext_87(79)/PMC8009331clean.pkl')
PMC8009331b
# Out:
#                                    Question  ...                                            Context
# 0            what are the treatment groups?  ...  intervention arm received weekly sessions refl...
# 1            what are the treatment groups?  ...  ited comprehensive cancer centers community-ba...
# 2            what are the treatment groups?  ...  rollment—participants (n = 256 patient-caregiv...
# 0       what is the scale of sleep measure?  ...  all) m.d. anderson symptom inventory (mdasi)23...
# 1       what is the scale of sleep measure?  ...  disturbance, depression. pittsburgh sleep symp...
# 2       what is the scale of sleep measure?  ...  dies- depression (cesd) scale, state anxiety s...
# 0  what is the scale of depression measure?  ...   promis depression item bank contain somatic i...
# 1  what is the scale of depression measure?  ...   profile v1.01—(patients caregivers). promis p...
# ...

# %%
answer = PMC3622018b['Answer'][0].tolist()
answers = ' '.join(answer)
#answers = answers.strip()
print(answers)

# %%
PMC3018656a = pd.read_pickle('/content/drive/MyDrive/fulltext_87(79)/PMC3018656.fulltxt.pkl')
PMC3018656a

# %%
PMC3018656b = pd.read_pickle('/content/drive/MyDrive/fulltext_87(79)/PMC3018656clean.pkl')
PMC3018656b
# Out:
#                                    Question  ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Context
# ...

# %%
PMC3871975a = pd.read_pickle('/content/drive/MyDrive/fulltext_87(79)/PMC3871975.fulltxt.pkl')
PMC3871975a

# %%
pd.set_option('display.max_colwidth', None)

# %%
PMC3871975b = pd.read_pickle('/content/drive/MyDrive/fulltext_87(79)/PMC3871975clean.pkl')
PMC3871975b
# Out:
#                                    Question  ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Context
# ...

# %%
PMC8009331 = pd.read_pickle('/content/drive/MyDrive/fulltext_87(79)/PMC8009331clean.pkl')
PMC8009331
# Out:
#                                    Question  ...                                            Context
# 0            what are the treatment groups?  ...  intervention arm received weekly sessions refl...
# 1            what are the treatment groups?  ...  ited comprehensive cancer centers community-ba...
# 2            what are the treatment groups?  ...  rollment—participants (n = 256 patient-caregiv...
# 0       what is the scale of sleep measure?  ...  all) m.d. anderson symptom inventory (mdasi)23...
# 1       what is the scale of sleep measure?  ...  disturbance, depression. pittsburgh sleep symp...
# 2       what is the scale of sleep measure?  ...  dies- depression (cesd) scale, state anxiety s...
# 0  what is the scale of depression measure?  ...   promis depression item bank contain somatic i...
# 1  what is the scale of depression measure?  ...   profile v1.01—(patients caregivers). promis p...
# ...

# %%
#PMC8009331 = PMC8009331.reset_index(drop=True)

# %%
PMC8009331['Context'][0]
# Out:
# 0    intervention arm received weekly sessions refl...
# 0    all) m.d. anderson symptom inventory (mdasi)23...
# 0     promis depression item bank contain somatic i...
# 0    mnia (pssq_i)24 center epidemiologic studies-d...
# 0     breast cancer patients caregivers: experience...
# Name: Context, dtype: object

# %%
fulltext88 = pd.read_pickle('/content/drive/MyDrive/HS651_CAMs_systematic_review_automation/df_fulltext88.pkl')
fulltext88

# %%
import pandas as pd

# %% [markdown]
# Concat_with_Answers_QA(Based on Jas Code)

# %%
QADF = pd.read_pickle('/content/drive/MyDrive/HS651_CAMs_systematic_review_automation/FulltextQA Concat/DFwithanswers.pkl')
QADF

# %%
import os
import glob

# %%
directory = os.path.abspath("/content/drive/MyDrive/fulltext_87(79)")
pickleFiles = glob.glob(os.path.join(directory, '*clean.pkl'))

# %%
pickleFiles
# Out:
# 75

# %%
rows = []
for PMCpickle in pickleFiles:
    #print(PMCpickle)
    pickldf = pd.read_pickle (PMCpickle)
    PMCNumb = str(PMCpickle[39:49])
    #print(PMCNumb)
    answer = pickldf['Answer'][0].tolist()
    answers = ' '.join(answer)
    context = pickldf['Context'][0].tolist()
    contexts = ' '.join(context)
    #type(PMCNumb)
    #print(answers)
    rows.append([PMCNumb,answers,contexts])
df = pd.DataFrame(rows,columns = ['PMCID','answers','contexts'])

# %%
dfQA = pd.read_pickle ('/content/drive/MyDrive/HS651_CAMs_systematic_review_automation/FulltextQA Concat/finetune75QA.pkl')

# %%
dfQA['PMCID'][14]
# Out:
# 'PMC3622018'

# %%
left = pd.read_pickle("/content/drive/MyDrive/HS651_CAMs_systematic_review_automation/FulltextQA Concat/finetune75QA.pkl")
left

# %%
right = pd.read_pickle('/content/drive/MyDrive/HS651_CAMs_systematic_review_automation/df_fulltext88.pkl')

# %%
dfmerg = pd.merge(left, right, how="left", on= 'PMCID')
dfmerg
# Out:
#          PMCID  ...  FuL
# 0   PMC3246091  ...  0.0
# 1   PMC3123409  ...  0.0
# 2   PMC3099500  ...  1.0
# 3   PMC3076132  ...  1.0
# 4   PMC3018656  ...  0.0
# ..         ...  ...  ...
# 71  PMC7771358  ...  1.0
# 72  PMC7764880  ...  1.0
# 73  PMC7763316  ...  0.0
# 74  PMC7735782  ...  1.0
# 75  PMC7607921  ...  NaN
#
# [76 rows x 11 columns]

# %%
#dfmerg[dfmerg.isna().any(axis=1)]
# Out:
#          PMCID                                            answers  ... PMID FuL
# 75  PMC7607921  study recruited total 32 people mild moderate ...  ...  NaN NaN
#
# [1 rows x 11 columns]

# %%
dfmerg = dfmerg.dropna()

# %%
dfmerg.to_pickle('/content/drive/MyDrive/HS651_CAMs_systematic_review_automation/df_fulltext75.pkl')

# %%
dfmerge = pd.read_pickle('/content/drive/MyDrive/HS651_CAMs_systematic_review_automation/df_fulltext75.pkl')

# %%
dfmerge['FuL'][0] = 1
dfmerge['FuL'][4] = 1
dfmerge['FuL'][9] = 1
dfmerge['FuL'][16] = 1
dfmerge['FuL'][17] = 0
dfmerge['FuL'][18] = 1
dfmerge['FuL'][21] = 1
dfmerge['FuL'][28] = 1
dfmerge['FuL'][30] = 0
dfmerge['FuL'][38] = 1
dfmerge['FuL'][39] = 1
dfmerge['FuL'][52] = 1
dfmerge['FuL'][61] = 1
dfmerge['FuL'][63] = 0
dfmerge['FuL'][66] = 1
dfmerge['FuL'][70] = 1
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
dfmerge = dfmerge.drop_duplicates('PMCID')

# %%
dfmerge
# Out:
#          PMCID  ...  FuL
# 0   PMC3246091  ...  1.0
# 1   PMC3123409  ...  0.0
# 2   PMC3099500  ...  1.0
# 3   PMC3076132  ...  1.0
# 4   PMC3018656  ...  1.0
# ..         ...  ...  ...
# 70  PMC8009331  ...  1.0
# 71  PMC7771358  ...  1.0
# 72  PMC7764880  ...  1.0
# 73  PMC7763316  ...  0.0
# 74  PMC7735782  ...  1.0
#
# [73 rows x 11 columns]

# %%
dfmerge.to_pickle('/content/drive/MyDrive/HS651_CAMs_systematic_review_automation/df_fulltext73_cor.pkl')

# %%
df = pd.read_pickle('/content/drive/MyDrive/HS651_CAMs_systematic_review_automation/df_fulltext73_cor.pkl')

# %%
df['FuL'].value_counts()
# Out:
# 1.0    49
# 0.0    24
# Name: FuL, dtype: int64
